# %%
from langgraph.graph import StateGraph,START,END
from langchain_openai import ChatOpenAI
# from langchain_community.chat_models import ChatOpenAI

from langchain.llms import openai
from typing import TypedDict
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI(
    model="google/gemma-3n-e2b-it:free",
    api_key=os.getenv("OPENROUTER_API_KEY"),
    base_url="https://openrouter.ai/api/v1",
    temperature=0.7
)

# %%
class BlogState(TypedDict):
    title:str
    outline:str
    content:str

# %%
def create_outline(state:BlogState) ->BlogState:
    #fetch title
    title=state['title']

    #call llm to gen outline
    prompt=f"Generate the detailed outline for a blog on the topic -{title}"
    outline=model.invoke(prompt).content
    #update state
    state['outline']=outline

    return state

# %%
def create_blog(state:BlogState)->BlogState:
    title=state['title']
    outline=state['outline']

    prompt=f"Write a detailed blog on the tilte -{title} using the following outline \n{outline} "
    content=model.invoke(prompt).content

    state['content']=content

    return state

# %%
graph=StateGraph(BlogState)

#nodes

graph.add_node('create_outline',create_outline)
graph.add_node('create_blog',create_blog)

#edges 
graph.add_edge(START,'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)

workflow=graph.compile()

# %%
initial_state={'title':'Rise of AI in India'}

final_state=workflow.invoke(initial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': '## Blog Outline: The Rise of AI in India - Opportunities, Challenges, and the Future\n\n**Target Audience:**  General public, students, entrepreneurs, policymakers, and anyone interested in the intersection of technology and India\'s development.\n\n**Overall Tone:**  Informative, optimistic, balanced, and insightful.  Avoid overly technical jargon.\n\n**Blog Length:** 1500-2000 words\n\n\n**I. Introduction (Approx. 200-250 words)**\n\n*   **Hook:** Start with a compelling statistic or a real-world example of AI\'s impact in India (e.g., AI-powered healthcare diagnostics, fintech innovations, agricultural applications).\n*   **Briefly define AI:**  A simple, accessible explanation of Artificial Intelligence and its subfields (Machine Learning, Deep Learning, NLP).  Avoid technical complexity.\n*   **Thesis Statement:**  India is experiencing a significant rise in AI adoption, driven by a confluence of factors. This blog explores the opportunities AI presents for India\'s economic growth and societal advancement, while also addressing the challenges that need to be overcome to ensure equitable and responsible implementation.\n*   **Roadmap:** Briefly outline the topics that will be covered in the blog post (e.g., current applications, key driving forces, challenges, future outlook).\n\n\n\n**II.  The Indian AI Landscape: Current Applications (Approx. 400-500 words)**\n\n*   **A.  Key Sectors Driving AI Adoption:**\n    *   **1. Healthcare:**\n        *   AI-powered diagnostics (image recognition for detecting diseases)\n        *   Personalized medicine and drug discovery\n        *   Virtual assistants for patient care\n        *   Telemedicine and remote monitoring\n    *   **2. Finance:**\n        *   Fraud detection and prevention\n        *   Algorithmic trading\n        *   Credit scoring and loan processing\n        *   Chatbots for customer service\n    *   **3.  Agriculture:**\n        *   Precision farming (analyzing soil data, predicting crop yields)\n        *   Automated irrigation systems\n        *   Disease detection in crops\n        *   Supply chain optimization\n    *   **4.  Retail:**\n        *   Personalized recommendations\n        *   Inventory management\n        *   Chatbots for customer support\n        *   Supply chain optimization\n    *   **5.  Manufacturing:**\n        *   Predictive maintenance\n        *   Quality control\n        *   Robotics and automation\n*   **B.  Examples of Successful AI Implementations in India:**\n    *   Highlight 2-3 specific companies or initiatives with notable AI applications in India (e.g.,  a healthcare startup using AI for diagnostics, a fintech company leveraging AI for fraud detection, an agricultural tech company deploying precision farming solutions).  Include brief case studies.\n*   **C.  The Growth of AI Startups in India:**\n    *   Mention the thriving AI startup ecosystem in India.\n    *   Highlight prominent AI startups and their areas of focus.\n\n\n\n**III.  Driving Forces Behind the AI Boom in India (Approx. 300-400 words)**\n\n*   **A.  Government Initiatives:**\n    *   **1.  "Digital India" Initiative:** How it\'s fostering digital infrastructure and data availability.\n    *   **2.  National AI Strategy:** Briefly discuss the government\'s vision and goals for AI development.\n    *   **3.  AI Policy Framework:** Mention any relevant policies or regulations supporting AI innovation.\n    *   **4.  Funding and Investment:**  Highlight government funding for AI research and development.\n*   **B.  Availability of Talent:**\n    *   Discuss the increasing number of AI professionals in India (graduates from top universities).\n    *   Mention the growth of AI-focused educational programs and training centers.\n    *   Highlight the efforts to attract global AI talent.\n*   **C.  Data Availability:**\n    *   Discuss the increasing availability of data in India (digital transformation, internet penetrati ...

# %%
print(final_state['title'])
# Out:
# Rise of AI in India

# %%
print(final_state['outline'])
# Out:
# ## Blog Outline: The Rise of AI in India - Opportunities, Challenges, and the Future
#
# **Target Audience:**  General public, students, entrepreneurs, policymakers, and anyone interested in the intersection of technology and India's development.
#
# **Overall Tone:**  Informative, optimistic, balanced, and insightful.  Avoid overly technical jargon.
#
# **Blog Length:** 1500-2000 words
#
#
# **I. Introduction (Approx. 200-250 words)**
#
# *   **Hook:** Start with a compelling statistic or a real-world example of AI's impact in India (e.g., AI-powered healthcare diagnostics, fintech innovations, agricultural applications).
# *   **Briefly define AI:**  A simple, accessible explanation of Artificial Intelligence and its subfields (Machine Learning, Deep Learning, NLP).  Avoid technical complexity.
# *   **Thesis Statement:**  India is experiencing a significant rise in AI adoption, driven by a confluence of factors. This blog explores the opportunities AI presents for India's economic growth and societal advancement, while also addressing the challenges that need to be overcome to ensure equitable and responsible implementation.
# *   **Roadmap:** Briefly outline the topics that will be covered in the blog post (e.g., current applications, key driving forces, challenges, future outlook).
#
#
#
# **II.  The Indian AI Landscape: Current Applications (Approx. 400-500 words)**
#
# *   **A.  Key Sectors Driving AI Adoption:**
#     *   **1. Healthcare:**
#         *   AI-powered diagnostics (image recognition for detecting diseases)
#         *   Personalized medicine and drug discovery
#         *   Virtual assistants for patient care
#         *   Telemedicine and remote monitoring
#     *   **2. Finance:**
#         *   Fraud detection and prevention
#         *   Algorithmic trading
#         *   Credit scoring and loan processing
#         *   Chatbots for customer service
#     *   **3.  Agriculture:**
#         *   Precision farming (analyzing soil data, predicting crop yields)
#         *   Automated irrigation systems
#         *   Disease detection in crops
#         *   Supply chain optimization
#     *   **4.  Retail:**
#         *   Personalized recommendations
#         *   Inventory management
#         *   Chatbots for customer support
#         *   Supply chain optimization
#     *   **5.  Manufacturing:**
#         *   Predictive maintenance
#         *   Quality control
#         *   Robotics and automation
# *   **B.  Examples of Successful AI Implementations in India:**
#     *   Highlight 2-3 specific companies or initiatives with notable AI applications in India (e.g.,  a healthcare startup using AI for diagnostics, a fintech company leveraging AI for fraud detection, an agricultural tech company deploying precision farming solutions).  Include brief case studies.
# *   **C.  The Growth of AI Startups in India:**
#     *   Mention the thriving AI startup ecosystem in India.
#     *   Highlight prominent AI startups and their areas of focus.
#
#
#
# **III.  Driving Forces Behind the AI Boom in India (Approx. 300-400 words)**
#
# *   **A.  Government Initiatives:**
#     *   **1.  "Digital India" Initiative:** How it's fostering digital infrastructure and data availability.
#     *   **2.  National AI Strategy:** Briefly discuss the government's vision and goals for AI development.
#     *   **3.  AI Policy Framework:** Mention any relevant policies or regulations supporting AI innovation.
#     *   **4.  Funding and Investment:**  Highlight government funding for AI research and development.
# *   **B.  Availability of Talent:**
#     *   Discuss the increasing number of AI professionals in India (graduates from top universities).
#     *   Mention the growth of AI-focused educational programs and training centers.
#     *   Highlight the efforts to attract global AI talent.
# *   **C.  Data Availability:**
#     *   Discuss the increasing availability of data in India (digital transformation, internet penetration).
#     *   Mention initiatives to promote data sharing and accessibility (while respecting privacy concerns).
# *   **D.  Cost-Effectiveness:**
#     *   Explain how AI solutions are becoming increasingly affordable, making them accessible to a wider range of businesses.
#
#
#
# **IV.  Challenges to AI Adoption in India (Approx. 400-500 words)**
#
# *   **A.  Data Privacy and Security:**
#     *   Discuss concerns about data security and privacy regulations.
#     *   Highlight the need for robust data governance frameworks.
#     *   Mention the importance of ethical data handling practices.
# *   **B.  Skills Gap:**
#     *   Acknowledge the shortage of skilled AI professionals (data scientists, machine learning engineers, AI ethicists).
#     *   Discuss the need for upskilling and reskilling initiatives.
#     *   Highlight the importance of fostering a culture of lifelong learning.
# *   **C.  Infrastructure Limitations:**
#     *   Mention the need for improved digital infrastructure (reliable internet connectivity, computing power) in rural areas.
#     *   Discuss the challenges of deploying AI in areas with limited resources.
# *   **D.  Ethical Concerns:**
#     *   Address potential biases in AI algorithms.
#     *   Discuss the implications of AI for job displacement.
#     *   Highlight the need for responsible AI development and deployment.
# *   **E.  Regulatory Uncertainty:**
#     *   Acknowledge the lack of clear regulations in some areas of AI.
#     *   Discuss the need for a balanced regulatory framework that promotes innovation while mitigating risks.
#
#
#
# **V.  The Future of AI in India (Approx. 300-400 words)**
#
# *   **A.  Potential for Economic Growth:**
#     *   Project the potential economic impact of AI on India (job creation, GDP growth).
#     *   Discuss the role of AI in transforming key industries.
# *   **B.  Emerging Trends:**
#     *   **1.  AI and Edge Computing:**  Explain how edge computing will enable AI applications in areas with limited connectivity.
#     *   **2.  AI and Quantum Computing:** Briefly discuss the potential of quantum computing to accelerate AI development.
#     *   **3.  AI and the Metaverse:**  Explore the potential applications of AI in the metaverse.
# *   **C.  India's Role on the Global AI Stage:**
#     *   Discuss India's potential to become a global leader in AI.
#     *   Highlight the importance of international collaboration in AI research and development.
#
#
#
# **VI. Conclusion (Approx. 100-150 words)**
#
# *   **Recap Key Points:** Briefly summarize the main takeaways from the blog post.
# *   **Reiterate Thesis:**  Restate the importance of AI for India's future.
# *   **Call to Action:** Encourage readers to learn more about AI, explore its applications, and contribute to its responsible development.
# *   **Final Thought:**  End with an optimistic outlook on the future of AI in India.
#
#
#
# **VII.  Resources (Optional)**
#
# *   Link to relevant government websites (NITI Aayog, Ministry of Electronics and Information Technology).
# *   Link to reputable AI research institutions in India.
# *   Link to AI-related news articles and reports.
# *   Link to relevant online courses and resources.
#
#
#
# **Key Considerations:**
#
# *   **Visuals:** Incorporate relevant images, charts, and graphs throughout the blog post to make it more engaging.
# *   **SEO:**  Optimize the blog post for search engines by using relevant keywords.
# *   **Readability:**  Write in a clear and concise style, using short paragraphs and bullet points.
# *   **Internal and External Links:**  Link to other relevant blog posts and external resources.
#
#
#
# This detailed outline provides a comprehensive framework for your blog post on the rise of AI in India. Remember to tailor the content and examples to your target audience and maintain a balanced and informative tone.  Good luck!

# %%
print(final_state['content'])
# Out:
# ## The Rise of AI in India: Opportunities, Challenges, and the Future
#
# **Introduction**
#
# Imagine a world where healthcare diagnostics are faster and more accurate, where farmers can optimize crop yields with pinpoint precision, or where fraud detection in financial transactions is virtually foolproof. This isn’t science fiction; it's the rapidly approaching reality powered by Artificial Intelligence (AI).  A recent report estimates that the Indian AI market is projected to reach $17.7 billion by 2025 – a testament to the burgeoning opportunities this technology presents.  But what exactly *is* AI, and how is it reshaping India's landscape?
#
# Simply put, AI is about creating machines that can perform tasks that typically require human intelligence.  It encompasses various fields, including Machine Learning (ML), where systems learn from data without explicit programming; Deep Learning, a subset of ML using artificial neural networks; and Natural Language Processing (NLP), which allows computers to understand and respond to human language.
#
# India is experiencing a significant rise in AI adoption, driven by a confluence of factors. This blog explores the immense opportunities AI presents for India's economic growth and societal advancement, while also addressing the challenges that need to be overcome to ensure equitable and responsible implementation.
#
#
#
# **II. The Indian AI Landscape: Current Applications**
#
# The impact of AI is already being felt across various sectors in India.  Here’s a glimpse into some key areas:
#
# **A. Key Sectors Driving AI Adoption:**
#
# *   **Healthcare:**  AI is revolutionizing healthcare, particularly in diagnostics.  AI-powered image recognition algorithms are being used to detect diseases like cancer and diabetic retinopathy with remarkable accuracy. Personalized medicine is also gaining traction, with AI helping to tailor treatments based on individual patient data.  Virtual assistants are providing round-the-clock patient support, and telemedicine platforms leverage AI for remote monitoring and consultations.
# *   **Finance:**  The financial sector is a prime beneficiary of AI’s ability to analyze vast datasets.  AI algorithms are being used to detect fraudulent transactions, preventing billions of dollars in losses. Algorithmic trading utilizes AI to execute trades at optimal times, while AI-powered credit scoring models offer more accurate risk assessments. Chatbots are providing instant customer service, addressing queries and resolving issues efficiently.
# *   **Agriculture:**  India’s agricultural sector is ripe for AI-driven transformation.  Precision farming techniques use AI to analyze soil data, predict crop yields, and optimize irrigation.  Automated irrigation systems conserve water and improve crop health. AI is even being used to detect diseases in crops early, minimizing losses.  Furthermore, AI is optimizing supply chains, ensuring efficient distribution of agricultural products.
# *   **Retail:**  E-commerce giants are leveraging AI for personalized recommendations, tailoring product suggestions to individual customer preferences.  AI-powered inventory management systems optimize stock levels, minimizing waste. Chatbots are providing enhanced customer support, resolving queries instantly. AI is also streamlining logistics and supply chain operations.
# *   **Manufacturing:**  AI is driving efficiency and productivity in manufacturing. Predictive maintenance algorithms analyze sensor data to anticipate equipment failures, minimizing downtime.  Quality control systems utilize AI to detect defects in real-time, ensuring product quality.  Robotics and automation, powered by AI, are transforming manufacturing processes.
#
# **B. Examples of Successful AI Implementations in India:**
#
# *   **Butterfly Network:** This Indian startup has developed a handheld ultrasound device powered by AI. The device is affordable and accessible, allowing healthcare professionals in remote areas to perform basic diagnostic scans.  This is particularly impactful in rural India where access to advanced medical equipment is limited.
# *   **Practo:**  A leading online healthcare platform, Practo utilizes AI to match patients with doctors, schedule appointments, and provide personalized health recommendations. Their AI-powered chatbots handle routine inquiries and guide patients towards appropriate care.
# *   **Farmly:**  A platform connecting farmers with AI-powered solutions for crop management. Farmly utilizes satellite imagery and machine learning to analyze crop health, predict yields, and recommend optimal farming practices.
#
# **C. The Growth of AI Startups in India:**
#
# India boasts a dynamic and vibrant AI startup ecosystem.  Companies like Google India, Microsoft India, and Amazon Web Services are investing heavily in AI research and development.  Numerous startups are focusing on niche areas like AI for healthcare, fintech, and agriculture. Some prominent AI startups include:
# *   **Affordable AI:**  Focusing on accessible AI solutions for businesses.
# *   **Haptik:**  Building conversational AI platforms.
# *   **Zoho:**  Leveraging AI for its various software products.
#
#
#
# **III. Driving Forces Behind the AI Boom in India**
#
# Several factors are fueling the rapid growth of AI in India:
#
# **A. Government Initiatives:**
#
# *   **"Digital India" Initiative:**  This ambitious program has significantly boosted digital infrastructure across the country, providing access to data and connectivity for AI applications.
# *   **National AI Strategy:**  The Indian government has outlined a comprehensive National AI Strategy with clear goals for promoting AI research, development, and adoption. This strategy includes initiatives to foster innovation, attract talent, and build a robust AI ecosystem.
# *   **AI Policy Framework:**  The government has introduced various policies and regulations to support AI innovation, including guidelines for data governance and ethical AI development.
# *   **Funding and Investment:**  The government has allocated significant funding for AI research and development, and private sector investment in AI is steadily increasing.
#
# **B. Availability of Talent:**
#
# India has a large pool of skilled professionals, with a growing number of graduates specializing in computer science, data science, and related fields.  Top universities across the country are offering AI-focused programs, and numerous training centers are providing upskilling opportunities.  Efforts are underway to attract global AI talent to India.
#
# **C. Data Availability:**
#
# India’s rapid digital transformation has led to a surge in data availability.  The proliferation of smartphones, the growth of e-commerce, and the increasing adoption of digital services have generated vast amounts of data that can be used to train AI models.
#
# **D. Cost-Effectiveness:**
#
# Cloud computing platforms are making AI tools and resources more affordable and accessible to businesses of all sizes.  This cost-effectiveness is a major driver of AI adoption in India.
#
#
#
# **IV. Challenges to AI Adoption in India**
#
# Despite the immense potential, AI adoption in India faces several challenges:
#
# **A. Data Privacy and Security:**
#
# Concerns about data privacy and security are paramount.  India has a complex legal framework governing data protection, and ensuring compliance with these regulations is crucial.  Robust data governance frameworks are needed to protect sensitive data and prevent misuse.
#
# **B. Skills Gap:**
#
# A significant skills gap remains in India, particularly in areas like data science, machine learning engineering, and AI ethics.  Addressing this gap requires investing in upskilling and reskilling initiatives, fostering a culture of lifelong learning, and attracting talent from abroad.
#
# **C. Infrastructure Limitations:**
#
# While digital infrastructure is improving, challenges remain in rural areas.  Limited internet connectivity and unreliable power supply can hinder AI deployment.  Investing in infrastructure upgrades is essential to ensure equitable access to AI.
#
# **D. Ethical Concerns:**
#
# AI algorithms can be biased, leading to unfair or discriminatory outcomes.  It's crucial to address these biases and ensure that AI systems are developed and deployed responsibly.  Ethical AI frameworks are needed to guide the development and use of AI.  Furthermore, the potential displacement of jobs due to AI automation requires proactive measures to support affected workers.
#
#
#
# **V. The Future of AI in India**
#
# The future of AI in India is exceptionally bright.
#
# **A. Potential for Economic Growth:**
#
# AI has the potential to transform India’s economy, driving job creation, boosting productivity, and fostering innovation.  Estimates suggest that AI could contribute trillions of dollars to India's GDP in the coming years.
#
# **B. Emerging Trends:**
#
# *   **AI and Edge Computing:** Edge computing will enable AI applications to be deployed in areas with limited connectivity, such as remote villages and industrial sites.
# *   **AI and Quantum Computing:** Quantum computing has the potential to accelerate AI development, enabling the creation of more powerful and sophisticated AI models.
# *   **AI and the Metaverse:** AI will play a crucial role in shaping the metaverse, powering virtual avatars, personalized experiences, and immersive interactions.
#
# **C. India's Role on the Global AI Stage:**
#
# India has the potential to become a global leader in AI.  Its large talent pool, vast data resources, and supportive government policies provide a strong foundation for AI innovation.  Collaboration with international partners will be essential to realize this potential.
#
#
#
# **Conclusion**
#
# The rise of AI in India is a transformative force, poised to reshape industries, improve lives, and drive economic growth. While challenges remain, the opportunities are immense.  By addressing data privacy concerns, bridging the skills gap, investing in infrastructure, and promoting ethical AI development, India can unlock the full potential of AI and build a brighter future for all.  The journey has just begun, and the possibilities are truly limitless.
#
#
#
# **Resources**
#
# *   NITI Aayog: [https://www.niti.gov.in/](https://www.niti.gov.in/)
# *   Ministry of Electronics and Information Technology (MeitY): [https://www.meity.gov.in/](https://www.meity.gov.in/)
# *   AI India: [https://www.aiindia.org/](https://www.aiindia.org/)
# *   [https://www.economist.com/technology/artificial-intelligence-in-india](https://www.economist.com/technology/artificial-intelligence-
